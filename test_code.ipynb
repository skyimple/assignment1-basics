# %%
import torch
from einops import rearrange, einsum

# %%
images = torch.randn(64, 128, 128, 3)
dim_by = torch.linspace(start=0.0, end=1.0, steps=10)

# %%
dim_value = rearrange(dim_by, "dim_value -> 1 dim_value 1 1 1")
images_rearr = rearrange(images, "b height width channel -> b 1 height width channel")

# %%
images_rearr.shape
# Out:
# torch.Size([64, 1, 128, 128, 3])

# %%
utf8_encoded = test_string.encode('utf-8')

# %%
print(utf8_encoded)
# Out:
# b'Hello!\xe4\xb8\xad\xe5\x9b\xbd'

# %%
text = 'hello!中国'
text_encoded = text.encode()
[bytes([b]).decode('utf-8') for b in text_encoded]

# %%
text_encoded.decode()
# Out:
# 'hello!中国'

# %%
text -> unicode -> utf-8
# Out:
#   Cell In[7], line 1
#     text -> unicode -> utf-8
#          ^
# SyntaxError: invalid syntax

# %%
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
test = "low wall"
test_encoded = test.encode(encoding='utf-8')
test_splited = test.split(' ')

# %%
re.findall(PAT, "some text that i'll pre-tokenize")
# Out:
# ['some', ' text', ' that', ' i', "'ll", ' pre', '-', 'tokenize']

# %%
test = "low wall"
test_encoded = test.encode(encoding='utf-8')
test_splited = test.split(' ')

# %%
[x.encode() for x in test_splited]
# Out:
# [b'low', b'wall']

# %%
bs = list(range(ord("!"), ord("~") + 1)) + list(range(ord("¡"), ord("¬") + 1)) + list(range(ord("®"), ord("ÿ") + 1))

# %%
from tests.common import  gpt2_bytes_to_unicode

# %%
from __future__ import annotations

import os
from collections import defaultdict
from typing import BinaryIO

import regex

# GPT-2 pre-tokenization pattern (from the spec).
# Uses \p{L}, \p{N}, and a negative lookahead that stdlib `re` does not support.
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""


def _pretokenize(text: str) -> list[bytes]:
    """Apply the GPT-2 pre-tokenization regex to `text`, returning a list of
    word-bytes. Each word is a UTF-8-encoded pre-token; downstream BPE will
    further split each word into single bytes and merge from there.
    """
    return [m.group().encode("utf-8") for m in regex.finditer(PAT, text)]

# %%
text = "Hello, world! 你好 123"

# %%
text_encode = _pretokenize(text)

# %%
from tests.common import FIXTURES_PATH, gpt2_bytes_to_unicode

# %%
reference_vocab_path = FIXTURES_PATH / "train-bpe-reference-vocab.json"
reference_merges_path = FIXTURES_PATH / "train-bpe-reference-merges.txt"

# %%
gpt2_byte_decoder = {v: k for k, v in gpt2_bytes_to_unicode().items()}

# %%
with open(reference_merges_path, encoding="utf-8") as f:
    gpt2_reference_merges = [tuple(line.rstrip().split(" ")) for line in f]
    # print(gpt2_reference_merges)
    reference_merges = [
        (
            bytes([gpt2_byte_decoder[token] for token in merge_token_1]),
            bytes([gpt2_byte_decoder[token] for token in merge_token_2]),
        )
        for merge_token_1, merge_token_2 in gpt2_reference_merges
    ]
# Out:
# [('Ġ', 't'), ('Ġ', 'a'), ('h', 'e'), ('i', 'n'), ('Ġt', 'he'), ('r', 'e'), ('Ġ', 'o'), ('Ġ', ','), ('e', 'r'), ('Ġ', 's'), ('a', 't'), ('Ġ', '.'), ('n', 'd'), ('i', 's'), ('o', 'r'), ('Ġ', 'w'), ('Ġ', 'c'), ('o', 'n'), ('Ġ', 'b'), ('Ġ', 'f'), ('o', 'u'), ('i', 't'), ('e', 'n'), ('e', 's'), ('Ġo', 'f'), ('Ġ', 'p'), ('in', 'g'), ('Ġ', 'in'), ('e', 'd'), ('a', 'l'), ('Ġ', 'm'), ('Ġa', 'nd'), ('Ġ', 'd'), ('a', 'n'), ('a', 'r'), ('Ġt', 'o'), ('o', 'm'), ('Ġt', 'h'), ('i', 'c'), ('i', 'on'), ('Ġ', 'h'), ('Ġ', 'l'), ('Ġ', 'y'), ('Ġ', 'e'), ('a', 's'), ('o', 't'), ('i', 'l'), ('Ġ', 'n'), ('Ġ', 'u'), ('en', 't'), ('Ġb', 'e'), ('Ġ', '&'), ('Ġ', 'is'), ('Ġy', 'ou'), ('o', 's'), ('Ġ', 're'), ('e', 't'), ('Ġf', 'or'), ('u', 't'), ('e', 'l'), ('Ġ', 'g'), ('a', 'y'), ('s', 't'), ('o', 'w'), ('l', 'e'), ('c', 'e'), ('a', 'd'), ('Ġo', 'n'), ('Ġ', 'I'), ('v', 'er'), ('v', 'e'), ('Ġ', 'A'), ('u', 'r'), ('o', 'l'), ('c', 't'), ('q', 'u'), ('Ġth', 'at'), ('i', 'm'), ('al', 'l'), ('a', 'm'), ('i', 'g'), ('c', 'h'), ('at', 'ion'), ('Ġ', 'P'), ('it', 'h'), ('i', 'r'), ('Ġ', 'S'), ('Ġ', 'it'), ('Ġp', 'r'), ('a', 'p'), ('Ġs', 'h'), ('Ġ', 'C'), ('t', 'h'), ('Ġc', 'om'), ('Ġ', '@'), ('Ġw', 'h'), ('-', '@'), ('Ġa', 're'), ('Ġ@', '-@'), ('n', 't'), ('i', 'd'), ('Ġw', 'ith'), ('Ġa', 'l'), ('o', 'p'), ('Ġu', 's'), ('er', 's'), ('Ġa', 's'), ('t', 'he'), ('a', 'nd'), ('i', 'f'), ('or', 'd'), ('o', 'd'), ('Ġ', 'he'), ('is', 't'), ('qu', 'ot'), ('m', 'ent'), ('Ġ', 'M'), ('Ġo', 'r'), ('o', 're'), ('Ġ', 'G'), ('Ġf', 'r'), ('il', 'l'), ('re', 's'), ('Ġs', 't'), ('es', 's'), ('l', 'd'), ('Ġth', 'is'), ('Ġ', '2'), ('ar', 't'), ('Ġ', ';'), ('Ġ', 'L'), ('l', 'y'), ('a', 'in'), ('u', 'l'), ('Ġd', 'e'), ('Ġc', 'on'), ('es', 't'), ('s', 'e'), ('ap', 'os'), ('a', 'g'), ('Ġfr', 'om'), ('Ġa', 'n'), ('Ġw', 'e'), ('Ġ', '('), ('0', '0'), ('t', 'er'), ('Ġ', 'E'), ('e', 'm'), ('a', 've'), ('Ġn', 'ot'), ('Ġ', ')'), ('Ġ', '1'), ('Ġyou', 'r'), ('o', 'c'), ('Ġc', 'an'), ('Ġb', 'y'), ('Ġ', 'D'), ('Ġn', 'e'), ('Ġ', 'v'), ('ig', 'h'), ('ic', 'h'), ('Ġal', 'l'), ('r', 'i'), ('Ġu', 'p'), ('Ġ', 'r'), ('Ġ', 'W'), ('b', 'le'), ('Ġthe', 'y'), ('Ġ', 'B'), ('u', 'n'), ('Ġy', 'e'), ('Ġwh', 'ich'), ('Ġ', 'O'), ('k', 'e'), ('Ġw', 'or'), ('Ġs', 'u'), ('Ġ', 'F'), ('Ġ', 'H'), ('Ġh', 'ave'), ('at', 'e'), ('Ġsh', 'all'), ('Ġc', 'h'), ('e', 'ct'), ('it', 'y'), ('Ġs', 'p'), ('res', 's'), ('igh', 't'), ('Ġw', 'ill'), ('Ġcom', 'p'), ('or', 't'), ('an', 't'), ('Ġ&', '#'), ('i', 've'), ('a', 're'), ('.', '.'), ('Ġe', 'x'), ('ĠA', 'nd'), ('Ġ.', '..'), ('as', 't'), ('2', '4'), ('Ġ', 'T'), ('ou', 'ld'), ('v', 'en'), ('Ġt', 'r'), ('u', 'st'), ('u', 'm'), ('ou', 't'), ('c', 'om'), ('Ġu', 'nt'), ('Ġs', 'e'), ('f', 't'), ('re', 'e'), ('os', 't'), ('o', 'g'), ('is', 'h'), ('ion', 's'), ('i', 'z'), ('1', '24'), ('Ġunt', 'o'), ('m', 'er'), ('ing', 's'), ('Ġa', 'c'), ('th', 'is'), ('at', 'ed'), ('a', 'c'), ('l', 'u'), ('e', 're'), ('Ġm', 'an'), ('f', 'or'), ('Ġm', 'y'), ('Ġa', 't'), ('i', 'es'), ('ag', 'e'), ('r', 'ou'), ('l', 'o'), ('an', 's'), ('p', 'p'), ('in', 'd'), ('Ġwor', 'k'), ('he', 're'), ('f', 'ore'), ('Ġs', 'it'), ('Ġ', 'ver')]

# %%
x = [(1,2),(3,4),(5,6)]

# %%
for idx, item in enumerate(x):
    print(idx, item)
# Out:
# 0 (1, 2)
# 1 (3, 4)
# 2 (5, 6)

# %%
text = "Hello"
text_encode = text.encode()
[bytes([b]) for b in text_encode]
# Out:
# [b'H', b'e', b'l', b'l', b'o']

# %%
# Out:
# [b'H', b'e', b'l', b'l', b'o']
